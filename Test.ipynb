# %% [markdown]
# <a href="https://colab.research.google.com/github/chinhnguyen25062001/CS112.L21.KHTN.N3/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/turkin501/CBIR.git
# Out:
# fatal: destination path 'CBIR' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install opencv-python==4.4.0.46
# !pip install opencv-contrib-python==4.4.0.46

# %%
# %cd /content/CBIR/image_search_engine
# Out:
# /content/CBIR/image_search_engine

# %% [markdown]
# # **Dataset chính thức**

# %%
# !python index_features.py --dataset /content/drive/MyDrive/CS336_ProjectIR/tai/db --features_db output/features.hdf5
# Out:
# [ WARN:0] global /tmp/pip-req-build-xgme2194/opencv_contrib/modules/xfeatures2d/misc/python/shadow_sift.hpp (13) SIFT_create DEPRECATED: cv.xfeatures2d.SIFT_create() is deprecated due SIFT tranfer to the main repository. https://github.com/opencv/opencv/issues/16736
# [PROGRESS] processed 10 images - 2022-01-29 03:35:59.400067
# [PROGRESS] processed 20 images - 2022-01-29 03:36:00.420592
# [PROGRESS] processed 30 images - 2022-01-29 03:36:01.269000
# [PROGRESS] processed 40 images - 2022-01-29 03:36:02.120683
# [PROGRESS] processed 50 images - 2022-01-29 03:36:02.885134
# [PROGRESS] processed 60 images - 2022-01-29 03:36:03.858272
# [PROGRESS] processed 70 images - 2022-01-29 03:36:04.655112
# [PROGRESS] processed 80 images - 2022-01-29 03:36:05.473751
# [PROGRESS] processed 90 images - 2022-01-29 03:36:06.395263
# [PROGRESS] processed 100 images - 2022-01-29 03:36:07.979909
# [PROGRESS] processed 110 images - 2022-01-29 03:36:08.923962
# ...

# %%
# !python cluster_features.py --features_db output/features.hdf5 --codebook output/vocab.cpickle --clusters 1100 --percentage 0.25
# Out:
# [INFO] starting sampling... - 2022-01-29 03:49:07.384916
# [INFO] sampled 1,110,648 features from a population of 4,442,592 - 2022-01-29 04:04:21.583999
# [INFO] clustering with k = 1,100 - 2022-01-29 04:04:21.584077
# tcmalloc: large alloc 1137303552 bytes == 0x55a6e99ec000 @  0x7efc117af1e7 0x7efc0f36f46e 0x7efc0f3bfc7b 0x7efc0f3c2e83 0x7efc0f3c307b 0x7efc0f464761 0x55a695104544 0x55a695104240 0x55a695178627 0x55a6951729ee 0x55a695105bda 0x55a695174737 0x55a695172ced 0x55a695044e2b 0x55a695174fe4 0x55a6951729ee 0x55a695105bda 0x55a695174737 0x55a6951729ee 0x55a695105bda 0x55a695173c0d 0x55a6951729ee 0x55a695105bda 0x55a695173c0d 0x55a6951729ee 0x55a6951726f3 0x55a69523c4c2 0x55a69523c83d 0x55a69523c6e6 0x55a695214163 0x55a695213e0c
# [INFO] cluster shape: (1100, 128) - 2022-01-29 04:05:09.236116
# [INFO] storing cluster centers...

# %% [markdown]
# ### Sửa dataset path

# %%
# !python visualize_centers.py --dataset /content/drive/MyDrive/CS336_ProjectIR/dataset --features_db /content/drive/MyDrive/CS336_ProjectIR/train_results/features.hdf5 --codebook output/vocab.cpickle --output output/vw_vis
# Out:
# [INFO] starting distance computations...
# Comparing:   0% |                                         | ETA:  1 day, 1:53:49

# %%
# !python extract_bovw.py --features_db /content/drive/MyDrive/CS336_ProjectIR/tai/db --codebook /content/drive/MyDrive/CS336_ProjectIR/tai/results/vocab.cpickle --bovw_db output/bovw.hdf5 --idf output/idf.cpickle
# Out:
# Traceback (most recent call last):
#   File "extract_bovw.py", line 27, in <module>
#     featuresDB = h5py.File(args["features_db"], mode = "r")
#   File "/usr/local/lib/python3.7/dist-packages/h5py/_hl/files.py", line 427, in __init__
#     swmr=swmr)
#   File "/usr/local/lib/python3.7/dist-packages/h5py/_hl/files.py", line 190, in make_fid
#     fid = h5f.open(name, flags, fapl=fapl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5f.pyx", line 96, in h5py.h5f.open
# OSError: Unable to open file (file read failed: time = Sat Jan 29 12:15:35 2022
# , filename = '/content/drive/MyDrive/CS336_ProjectIR/tai/db', file descriptor = 3, errno = 21, error message = 'Is a directory', buf = 0x7ffd7b6eb418, total read size = 8, bytes this sub-read = 8, bytes actually read = 18446744073709551615, offset = 0)

# %%
# %pip install redis-server redis

# %%
import subprocess
import redis_server
subprocess.Popen([redis_server.REDIS_SERVER_PATH])

# %%
# !python build_redis_index.py --bovw_db output/bovw.hdf5
# Out:
# [PROGRESS] processed 10 entries
# [PROGRESS] processed 20 entries
# [PROGRESS] processed 30 entries
# [PROGRESS] processed 40 entries
# [PROGRESS] processed 50 entries
# [PROGRESS] processed 60 entries
# [PROGRESS] processed 70 entries
# [PROGRESS] processed 80 entries
# [PROGRESS] processed 90 entries
# [PROGRESS] processed 100 entries
# [PROGRESS] processed 110 entries
# [PROGRESS] processed 120 entries
# [PROGRESS] processed 130 entries
# [PROGRESS] processed 140 entries
# [PROGRESS] processed 150 entries
# [PROGRESS] processed 160 entries
# [PROGRESS] processed 170 entries
# [PROGRESS] processed 180 entries
# [PROGRESS] processed 190 entries
# [PROGRESS] processed 200 entries
# [PROGRESS] processed 210 entries
# [PROGRESS] processed 220 entries
# [PROGRESS] processed 230 entries
# [PROGRESS] processed 240 entries
# [PROGRESS] processed 250 entries
# [PROGRESS] processed 260 entries
# [PROGRESS] processed 270 entries
# [PROGRESS] processed 280 entries
# ...

# %% [markdown]
# # cluster 600

# %%
# !python search.py --dataset /content/drive/MyDrive/CS336_ProjectIR/tai/db --features_db /content/drive/MyDrive/CS336_ProjectIR/tai/results/features.hdf5 --bovw_db output/bovw.hdf5 --codebook /content/drive/MyDrive/CS336_ProjectIR/chinh/Train_Results/vocab.cpickle  --idf output/idf.cpickle  --query /content/paris_defense_000605.jpg
# Out:
# [ WARN:0] global /tmp/pip-req-build-xgme2194/opencv_contrib/modules/xfeatures2d/misc/python/shadow_sift.hpp (13) SIFT_create DEPRECATED: cv.xfeatures2d.SIFT_create() is deprecated due SIFT tranfer to the main repository. https://github.com/opencv/opencv/issues/16736
# Traceback (most recent call last):
#   File "search.py", line 39, in <module>
#     idf = pickle.loads(open(args["idf"], "rb").read())
# FileNotFoundError: [Errno 2] No such file or directory: 'output/idf.cpickle'

# %% [markdown]
# # Cluster 1536

# %%
# !python search.py --dataset /content/drive/MyDrive/CS336_ProjectIR/dataset --features_db /content/drive/MyDrive/CS336_ProjectIR/train_results/features.hdf5 --bovw_db output/bovw.hdf5 --codebook /content/drive/MyDrive/CS336_ProjectIR/chinh/Train_Results/vocab.cpickle --query /content/drive/Shareddrives
# Out:
# [ WARN:0] global /tmp/pip-req-build-xgme2194/opencv_contrib/modules/xfeatures2d/misc/python/shadow_sift.hpp (13) SIFT_create DEPRECATED: cv.xfeatures2d.SIFT_create() is deprecated due SIFT tranfer to the main repository. https://github.com/opencv/opencv/issues/16736
# Traceback (most recent call last):
#   File "search.py", line 55, in <module>
#     queryImage = imutils.resize(queryImage, width = 320)
#   File "/usr/local/lib/python3.7/dist-packages/imutils/convenience.py", line 69, in resize
#     (h, w) = image.shape[:2]
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# !python search.py --dataset /content/drive/MyDrive/CS336_ProjectIR/dataset --features_db /content/drive/MyDrive/CS336_ProjectIR/train_results/features.hdf5 --bovw_db /content/drive/MyDrive/CS336_ProjectIR/train_results/bovw.hdf5 --codebook /content/drive/MyDrive/CS336_ProjectIR/train_results/vocab.cpickle  --query /content/paris_triomphe_000025_crop.jpg
# Out:
# [ WARN:0] global /tmp/pip-req-build-xgme2194/opencv_contrib/modules/xfeatures2d/misc/python/shadow_sift.hpp (13) SIFT_create DEPRECATED: cv.xfeatures2d.SIFT_create() is deprecated due SIFT tranfer to the main repository. https://github.com/opencv/opencv/issues/16736
# [INFO] search took: 2.88s
# [RESULT] 1. b'paris_triomphe_000466.jpg' - 670.23
# [RESULT] 2. b'paris_triomphe_000571.jpg' - 704.57
# [RESULT] 3. b'paris_triomphe_000569.jpg' - 723.45
# [RESULT] 4. b'paris_triomphe_000346.jpg' - 789.62
# [RESULT] 5. b'paris_triomphe_001083.jpg' - 796.77
# [RESULT] 6. b'paris_triomphe_000348.jpg' - 878.14
# [RESULT] 7. b'paris_triomphe_000477.jpg' - 886.82
# [RESULT] 8. b'paris_triomphe_000797.jpg' - 899.22
# [RESULT] 9. b'paris_triomphe_000583.jpg' - 906.68
# [RESULT] 10. b'paris_triomphe_000953.jpg' - 916.04
# [RESULT] 11. b'paris_triomphe_000804.jpg' - 935.50
# [RESULT] 12. b'paris_triomphe_000027.jpg' - 944.97
# [RESULT] 13. b'paris_triomphe_000018.jpg' - 989.72
# ...

# %%
import pickle

# %%
with open('/content/drive/MyDrive/CS336_ProjectIR/train_results/idf.cpickle', 'rb') as f:
    x = pickle.load(f)

# %%
print(x)
# Out:
# [1.14084505 0.84547204 2.0996954  0.81245864 1.0362201  0.83458659
#  1.05089682 0.77198969 1.39321045 0.94513316 0.85132643 1.17830261
#  0.88529126 0.97044063 1.22839133 0.82524745 0.82346141 1.03093607
#  1.02830449 0.64602926 1.12479803 1.6218898  1.32375502 1.07080698
#  1.11185752 1.21880659 0.83062477 1.22465301 0.99132693 1.02874261
#  0.8709676  1.03401503 1.58376772 1.2862109  1.55517285 0.77776907
#  0.86351045 0.78461138 1.05269054 0.79461664 0.98837646 0.73963736
#  0.65413133 0.7508586  1.1854528  0.82274789 1.13888619 1.04865918
#  0.7750452  1.3524137  1.19110689 1.01958224 0.79669925 1.23644939
#  0.98375751 0.98921856 1.0366617  0.9455363  1.14133537 0.66961668
#  0.7750452  1.0491063  2.1522009  1.83399223 0.8152865  0.65805586
#  1.57012081 1.01784688 0.83530862 1.16616286 1.00065694 0.78564178
#  1.17373292 1.05673822 0.90949993 0.98375751 1.10190718 1.20146967
#  1.70193251 0.96755105 1.16968842 1.49332712 1.08600414 1.31847176
# ...

# %%
import os

# %%
totalFiles=0
for base, dirs, files in os.walk('/content/drive/MyDrive/CS336_ProjectIR/Dataset_New'):
    print('Searching in : ',base)
    for Files in files:
        totalFiles += 1
print(totalFiles)
# Out:
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/pompidou
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/moulinrouge
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/general
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/triomphe
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/notredame
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/invalides
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/louvre
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/pantheon
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/sacrecoeur
# Searching in :  /content/drive/MyDrive/CS336_ProjectIR/Dataset_New/train/museedorsay
# ...
